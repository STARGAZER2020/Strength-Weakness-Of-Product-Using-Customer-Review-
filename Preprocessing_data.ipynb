# %%
import re
import nltk
import tokenize

# %%
reviews_train = []

for line in open('1234.txt','r'):
    reviews_train.append(line.strip())
reviews_train
# Out:
# ['',
#  '"I have purchased moto g5 plus 26 days back,from the very first day i am facing problems with this phone.Touch screen is not working properly,when i complained regarding the problem with flipcart they refused to take it back.Flipcart is cheating many people because they are not fulfilling return policy.I will never ever purchase anything from flipcart in future ,will not allow anybody from my circle to purchase anything from these cheaters.READ MORE"',
#  '"NO NATIVE (direct from phone with 3rd party app) VIDEO CALL OPTION AVAILABLE IN THIS PHONE AS LIKE IN SAMSUNG, MI AND OTHER BRANDS. MOTOROLA SHOULD PROVIDE THIS FUNCTION TO THEIR USERS OTHERWISE phone is good. camera in low light is very good. All over phone is good in this price range.READ MORE"',
#  '"Arguably the best all round smartphone under 20K.READ MORE"',
#  '"Mobile looking superREAD MORE"',
#  '"Performance wise no problem but I found heating issueREAD MORE"',
#  '"Use with charm, very good mobileREAD MORE"',
# ...

# %%
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

def preprocess_reviews(reviews):
    reviews = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews]
    reviews = [REPLACE_WITH_SPACE.sub(" ", line) for line in reviews]
    return reviews

# %%
reviews_clean = preprocess_reviews(reviews_train)
reviews_clean
# Out:
# ['',
#  'i have purchased moto g5 plus 26 days backfrom the very first day i am facing problems with this phonetouch screen is not working properlywhen i complained regarding the problem with flipcart they refused to take it backflipcart is cheating many people because they are not fulfilling return policyi will never ever purchase anything from flipcart in future will not allow anybody from my circle to purchase anything from these cheatersread more',
#  'no native direct from phone with 3rd party app video call option available in this phone as like in samsung mi and other brands motorola should provide this function to their users otherwise phone is good camera in low light is very good all over phone is good in this price rangeread more',
#  'arguably the best all round smartphone under 20kread more',
#  'mobile looking superread more',
#  'performance wise no problem but i found heating issueread more',
#  'use with charm very good mobileread more',
# ...

# %%
token = []
for i in reviews_clean:
    tokenizer = nltk.tokenize.TreebankWordTokenizer()
    tokens = token.append(tokenizer.tokenize(i))

# %%
token
# Out:
# [[],
#  ['i',
#   'have',
#   'purchased',
#   'moto',
#   'g5',
#   'plus',
#   '26',
#   'days',
#   'backfrom',
#   'the',
#   'very',
#   'first',
#   'day',
#   'i',
#   'am',
#   'facing',
#   'problems',
#   'with',
#   'this',
#   'phonetouch',
#   'screen',
#   'is',
#   'not',
#   'working',
#   'properlywhen',
#   'i',
#   'complained',
#   'regarding',
#   'the',
#   'problem',
#   'with',
#   'flipcart',
#   'they',
#   'refused',
#   'to',
#   'take',
#   'it',
#   'backflipcart',
#   'is',
#   'cheating',
#   'many',
#   'people',
#   'because',
#   'they',
#   'are',
#   'not',
#   'fulfilling',
#   'return',
#   'policyi',
#   'will',
#   'never',
#   'ever',
#   'purchase',
#   'anything',
#   'from',
#   'flipcart',
#   'in',
#   'future',
#   'will',
#   'not',
#   'allow',
#   'anybody',
#   'from',
#   'my',
#   'circle',
#   'to',
#   'purchase',
#   'anything',
#   'from',
#   'these',
#   'cheatersread',
#   'more'],
#  ['no',
#   'native',
#   'direct',
# ...

# %%
stemmer = nltk.stem.PorterStemmer()
" ".join(stemmer.stem(i) for j in token for i in j)
# Out:
# 'i have purchas moto g5 plu 26 day backfrom the veri first day i am face problem with thi phonetouch screen is not work properlywhen i complain regard the problem with flipcart they refus to take it backflipcart is cheat mani peopl becaus they are not fulfil return policyi will never ever purchas anyth from flipcart in futur will not allow anybodi from my circl to purchas anyth from these cheatersread more no nativ direct from phone with 3rd parti app video call option avail in thi phone as like in samsung mi and other brand motorola should provid thi function to their user otherwis phone is good camera in low light is veri good all over phone is good in thi price rangeread more arguabl the best all round smartphon under 20kread more mobil look superread more perform wise no problem but i found heat issueread more use with charm veri good mobileread more best phone till yet under 18kread more everyth ok in phone without speaker and microphon which have mani issu regard sound qualiti 
# ...

# %%
stemmer = nltk.stem.WordNetLemmatizer()
" ".join(stemmer.lemmatize(i) for j in token for i in j)
# Out:
# 'i have purchased moto g5 plus 26 day backfrom the very first day i am facing problem with this phonetouch screen is not working properlywhen i complained regarding the problem with flipcart they refused to take it backflipcart is cheating many people because they are not fulfilling return policyi will never ever purchase anything from flipcart in future will not allow anybody from my circle to purchase anything from these cheatersread more no native direct from phone with 3rd party app video call option available in this phone a like in samsung mi and other brand motorola should provide this function to their user otherwise phone is good camera in low light is very good all over phone is good in this price rangeread more arguably the best all round smartphone under 20kread more mobile looking superread more performance wise no problem but i found heating issueread more use with charm very good mobileread more best phone till yet under 18kread more everything ok in phone without spea
# ...
